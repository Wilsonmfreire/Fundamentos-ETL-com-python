# %%
import pandas as pd
import pandera as pa

# %%
valores_ausentes = ['***', '****' , '*****', '####','NULL']
df = pd.read_csv("ocorrencia.csv", sep = "," , parse_dates=["ocorrencia_dia"], dayfirst= True, na_values= valores_ausentes)
df.head(5)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia": pa.Column(pa.Int),
        "codigo_ocorrencia2":pa.Column(pa.Int),
        "ocorrencia_classificacao": pa.Column(pa.String),
        "ocorrencia_cidade": pa.Column(pa.String),
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable= True),
        "ocorrencia_aerodromo": pa.Column(pa.String,  nullable= True),
        "ocorrencia_dia": pa.Column(pa.DateTime),
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True),
        "total_recomendacoes": pa.Column(pa.Int)
    }
)

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
filtro = df.ocorrencia_aerodromo.isnull()
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 3                 39527               39527                 ACIDENTE
# 5                 39807               39807                INCIDENTE
# 7                 39707               39707          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6092              80236               80236                 ACIDENTE
# 6093              80227               80227                 ACIDENTE
# 6096              80229               80229                INCIDENTE
# 6099              80233               80233                 ACIDENTE
# 6112              80257               80257                 ACIDENTE
#
#        ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0         RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 3     LUCAS DO RIO VERDE            MT                  NaN     2010-01-04
# 5               SALVADOR            BA                  NaN     2010-01-06
# 7               CANUTAMA            AM                  NaN     2010-01-09
# 9          PARÁ DE MINAS            MG                  NaN     2010-01-10
# ...                  ...           ...                  ...            ...
# 6092              POCONÉ            MT                  NaN     2021-08-01
# 6093            UMUARAMA            PR                  NaN     2021-08-02
# 6096             ITAGUAÍ            RJ                  NaN     2021-08-05
# 6099              POCONÉ            MT                  NaN     2021-08-08
# 6112          DOM AQUINO            MT                  NaN     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 3           17:30:00                    0
# 5           17:53:00                    0
# 7           12:30:00                    3
# 9           20:00:00                    0
# ...              ...                  ...
# 6092        22:00:00                    0
# 6093        14:30:00                    0
# 6096        15:30:00                    0
# 6099        12:30:00                    0
# 6112        16:00:00                    0
#
# [2450 rows x 9 columns]

# %%
df.count()
# Out:
# codigo_ocorrencia           6114
# codigo_ocorrencia2          6114
# ocorrencia_classificacao    6114
# ocorrencia_cidade           6114
# ocorrencia_uf               6112
# ocorrencia_aerodromo        3664
# ocorrencia_dia              6114
# ocorrencia_hora             6113
# total_recomendacoes         6114
# dtype: int64

# %%
#ocorrência com mais de 10 recomendações
filtro = df.total_recomendacoes >10
df.loc[filtro,['ocorrencia_cidade', 'total_recomendacoes']]
# Out:
#          ocorrencia_cidade  total_recomendacoes
# 63               SÃO PAULO                   11
# 326         RIO DE JANEIRO                   19
# 530              SÃO PAULO                   11
# 727               ITÁPOLIS                   11
# 872                 RECIFE                   23
# 884   SÃO JOSÉ DOS PINHAIS                   11
# 1062            UBERLÂNDIA                   20
# 1972              BRASÍLIA                   11
# 2797                SANTOS                   13
# 3932               VITÓRIA                   12

# %%
#ocorrencia cuja classificação == INCIDENTE GRAVE
filtro = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 29                39709               39709          INCIDENTE GRAVE
# 35                39487               39487          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 6090              80221               80221          INCIDENTE GRAVE
# 6095              80228               80228          INCIDENTE GRAVE
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7             CANUTAMA            AM                  NaN     2010-01-09
# 8             CASCAVEL            PR                 SBCA     2010-01-10
# 9        PARÁ DE MINAS            MG                  NaN     2010-01-10
# 29            CURITIBA            PR                 SBBI     2010-01-23
# 35              PALMAS            TO                 SBPJ     2010-01-26
# ...                ...           ...                  ...            ...
# 6090             MARAÚ            BA                 SIRI     2021-07-31
# 6095   ELDORADO DO SUL            RS                 SIXE     2021-08-05
# 6097     CAXIAS DO SUL            RS                 SBCX     2021-08-06
# 6098   CHAPADÃO DO SUL            MS                 SSCD     2021-08-06
# 6104       VOTUPORANGA            SP                 SDVG     2021-08-11
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 29          16:36:00                    2
# 35          16:50:00                    0
# ...              ...                  ...
# 6090        13:15:00                    0
# 6095        15:55:00                    0
# 6097        16:59:00                    0
# 6098        20:00:00                    0
# 6104        19:09:00                    0
#
# [791 rows x 9 columns]

# %%
#ocorrencia cuja a classificação == INCIDENTE GRAVE e estado SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 & filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 136               40270               40270          INCIDENTE GRAVE
# 171               40620               40620          INCIDENTE GRAVE
# 219               41411               41411          INCIDENTE GRAVE
# 297               42289               42289          INCIDENTE GRAVE
# 314               42323               42323          INCIDENTE GRAVE
# ...                 ...                 ...                      ...
# 5949              80056               80056          INCIDENTE GRAVE
# 6000              80114               80114          INCIDENTE GRAVE
# 6007              80124               80124          INCIDENTE GRAVE
# 6081              80200               80200          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 136            PIRASSUNUNGA            SP                 SDPY     2010-04-15
# 171               GUARULHOS            SP                 SBGR     2010-05-06
# 219               SÃO PAULO            SP                 SBMT     2010-06-08
# 297               SÃO PAULO            SP                 SBMT     2010-07-29
# 314   SÃO JOSÉ DO RIO PRETO            SP                 SBSR     2010-08-05
# ...                     ...           ...                  ...            ...
# 5949          FERNANDÓPOLIS            SP                  NaN     2021-04-28
# 6000                   LINS            SP                 SWXQ     2021-06-05
# 6007              SÃO PAULO            SP                 SBSP     2021-06-10
# 6081      BRAGANÇA PAULISTA            SP                 SDVH     2021-07-25
# 6104            VOTUPORANGA            SP                 SDVG     2021-08-11
#
#      ocorrencia_hora  total_recomendacoes
# 136         20:15:00                    0
# 171         15:50:00                    0
# 219         19:30:00                    2
# 297         20:06:00                    0
# 314         12:01:00                    0
# ...              ...                  ...
# 5949        11:20:00                    0
# 6000        19:43:00                    0
# 6007        20:30:00                    0
# 6081        12:25:00                    0
# 6104        19:09:00                    0
#
# [145 rows x 9 columns]

# %%
#ocorrencia cuja a classificação == INCIDENTE GRAVE ou estado SP
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 7                 39707               39707          INCIDENTE GRAVE
# 8                 39156               39156          INCIDENTE GRAVE
# 9                 39711               39711          INCIDENTE GRAVE
# 11                40069               40069                 ACIDENTE
# 16                39809               39809                INCIDENTE
# ...                 ...                 ...                      ...
# 6097              80231               80231          INCIDENTE GRAVE
# 6098              80248               80248          INCIDENTE GRAVE
# 6104              80238               80238          INCIDENTE GRAVE
# 6108              80244               80244                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 7              CANUTAMA            AM                  NaN     2010-01-09
# 8              CASCAVEL            PR                 SBCA     2010-01-10
# 9         PARÁ DE MINAS            MG                  NaN     2010-01-10
# 11            SÃO PAULO            SP                 SBMT     2010-01-10
# 16            SÃO PAULO            SP                  NaN     2010-01-15
# ...                 ...           ...                  ...            ...
# 6097      CAXIAS DO SUL            RS                 SBCX     2021-08-06
# 6098    CHAPADÃO DO SUL            MS                 SSCD     2021-08-06
# 6104        VOTUPORANGA            SP                 SDVG     2021-08-11
# 6108  BRAGANÇA PAULISTA            SP                 SBBP     2021-08-15
# 6113           CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 7           12:30:00                    3
# 8           23:15:00                    2
# 9           20:00:00                    0
# 11          14:50:00                    8
# 16          15:00:00                    0
# ...              ...                  ...
# 6097        16:59:00                    0
# 6098        20:00:00                    0
# 6104        19:09:00                    0
# 6108        15:20:00                    0
# 6113        12:45:00                    0
#
# [2110 rows x 9 columns]

# %%
#ocorrencia cuja a classificação == INCIDENTE GRAVE ou classificação == INCIDENTE e o estado SP
filtro1 = (df.ocorrencia_classificacao == 'INCIDENTE GRAVE') | (df.ocorrencia_classificacao == 'INCIDENTE')
filtro2 = df.ocorrencia_uf == 'SP'
df.loc[filtro1 | filtro2]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                 40211               40211                INCIDENTE
# 1                 40349               40349                INCIDENTE
# 2                 40351               40351                INCIDENTE
# 4                 40324               40324                INCIDENTE
# 5                 39807               39807                INCIDENTE
# ...                 ...                 ...                      ...
# 6108              80244               80244                INCIDENTE
# 6109              80245               80245                INCIDENTE
# 6110              80247               80247                INCIDENTE
# 6111              80251               80251                INCIDENTE
# 6113              80259               80259                INCIDENTE
#
#       ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0        RIO DE JANEIRO            RJ                  NaN     2010-01-03
# 1                 BELÉM            PA                 SBBE     2010-01-03
# 2        RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 4               PELOTAS            RS                 SBPK     2010-01-05
# 5              SALVADOR            BA                  NaN     2010-01-06
# ...                 ...           ...                  ...            ...
# 6108  BRAGANÇA PAULISTA            SP                 SBBP     2021-08-15
# 6109             RECIFE            PE                 SBRF     2021-08-15
# 6110        PORTO VELHO            RO                 SBPV     2021-08-16
# 6111              BELÉM            PA                 SBBE     2021-08-17
# 6113           CAMPINAS            SP                 SBKP     2021-08-18
#
#      ocorrencia_hora  total_recomendacoes
# 0           12:00:00                    0
# 1           11:05:00                    0
# 2           03:00:00                    0
# 4           19:25:00                    0
# 5           17:53:00                    0
# ...              ...                  ...
# 6108        15:20:00                    0
# 6109        15:05:00                    0
# 6110        02:30:00                    0
# 6111        15:45:00                    0
# 6113        12:45:00                    0
#
# [4590 rows x 9 columns]

# %%
#ocorrencia cuja a cidade contém (em qualquer parte do conteúdo) os caracteres MA
filtro =  df.ocorrencia_cidade.str.contains('MA | AL')
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 110               40089               40089                 ACIDENTE
# 130               40258               40258                INCIDENTE
# 131               40327               40327                INCIDENTE
# 133               40248               40248                INCIDENTE
# 156               40572               40572                 ACIDENTE
# ...                 ...                 ...                      ...
# 5849              79912               79912                INCIDENTE
# 5851              79920               79920                INCIDENTE
# 5906              80023               80023                INCIDENTE
# 5916              80027               80027                INCIDENTE
# 5999              80120               80120                INCIDENTE
#
#                      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# 110   VILA BELA DA SANTÍSSIMA TRINDADE            MT                  NaN
# 130                       MONTE ALEGRE            PA                  NaN
# 131                       PORTO ALEGRE            RS                  NaN
# 133                       PORTO ALEGRE            RS                 SBPA
# 156                       PORTO ALEGRE            RS                 SBPA
# ...                                ...           ...                  ...
# 5849                      PORTO ALEGRE            RS                 SBPA
# 5851                      PORTO ALEGRE            RS                 SBPA
# 5906                      PORTO ALEGRE            RS                 SBPA
# 5916                      PORTO ALEGRE            RS                 SBPA
# 5999                      PORTO ALEGRE            RS                 SBPA
#
#      ocorrencia_dia ocorrencia_hora  total_recomendacoes
# 110      2010-03-28        15:10:00                    0
# 130      2010-04-12        18:10:00                    0
# 131      2010-04-12        13:13:00                    0
# 133      2010-04-13        18:47:00                    0
# 156      2010-04-28        14:10:00                    0
# ...             ...             ...                  ...
# 5849     2021-02-23        16:12:00                    0
# 5851     2021-02-24        02:57:00                    0
# 5906     2021-03-29        18:24:00                    0
# 5916     2021-04-07        19:47:00                    0
# 5999     2021-06-04        23:31:00                    0
#
# [144 rows x 9 columns]

# %%
#ocorrencia cuja a cidade termine com os caracteres MA
filtro =  df.ocorrencia_cidade.str[-1] == 'M'
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 1                 40349               40349                INCIDENTE
# 36                39850               39850                INCIDENTE
# 40                39158               39158                INCIDENTE
# 92                40322               40322                INCIDENTE
# 93                40307               40307                INCIDENTE
# ...                 ...                 ...                      ...
# 5922              80019               80019                 ACIDENTE
# 5937              80040               80040                INCIDENTE
# 5974              80085               80085          INCIDENTE GRAVE
# 6062              80190               80190                INCIDENTE
# 6111              80251               80251                INCIDENTE
#
#      ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 1                BELÉM            PA                 SBBE     2010-01-03
# 36               BELÉM            PA                 SBJC     2010-01-26
# 40               BELÉM            PA                  NaN     2010-01-28
# 92               BELÉM            PA                 SBJC     2010-03-15
# 93               BELÉM            PA                 SBJC     2010-03-16
# ...                ...           ...                  ...            ...
# 5922        NOVA MUTUM            MT                  NaN     2021-04-12
# 5937             BELÉM            PA                 SBBE     2021-04-20
# 5974          SANTARÉM            PA                 SNCJ     2021-05-13
# 6062          SANTARÉM            PA                 SBSN     2021-07-11
# 6111             BELÉM            PA                 SBBE     2021-08-17
#
#      ocorrencia_hora  total_recomendacoes
# 1           11:05:00                    0
# 36          14:30:00                    0
# 40          16:00:00                    0
# 92          18:15:00                    0
# 93          20:00:00                    0
# ...              ...                  ...
# 5922        11:00:00                    0
# 5937        17:10:00                    0
# 5974        19:30:00                    0
# 6062        21:30:00                    0
# 6111        15:45:00                    0
#
# [181 rows x 9 columns]

# %%
#ocorrencia do ano de 2015
filtro = (df.ocorrencia_dia.dt.year == 2015) & (df.ocorrencia_dia.dt.month == 12) & (df.ocorrencia_dia.dt.day > 2 ) & (df.ocorrencia_dia.dt.day < 9)
df.loc[filtro]
# Out:
#       codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 3434              53575               53575                INCIDENTE
# 3435              60637               60637                INCIDENTE
# 3436              53625               53625                 ACIDENTE
# 3437              53626               53626                 ACIDENTE
# 3438              53628               53628                 ACIDENTE
# 3439              53629               53629          INCIDENTE GRAVE
# 3440              53631               53631                INCIDENTE
# 3441              60636               60636                INCIDENTE
#
#           ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 3434  CAMPOS DOS GOYTACAZES            RJ                 SBFS     2015-12-03
# 3435         BELO HORIZONTE            MG                 SBBH     2015-12-03
# 3436               TRINDADE            GO                  NaN     2015-12-06
# 3437              AMERICANA            SP                 SDAI     2015-12-06
# 3438                  AGUAÍ            SP                  NaN     2015-12-08
# 3439                  JALES            SP                 SDJL     2015-12-08
# 3440               CAMPINAS            SP                 SBKP     2015-12-08
# 3441          CAXIAS DO SUL            RS                 SBCX     2015-12-08
#
#      ocorrencia_hora  total_recomendacoes
# 3434        10:50:00                    0
# 3435        16:47:00                    0
# 3436        13:10:00                    3
# 3437        15:00:00                    1
# 3438        14:30:00                    1
# 3439        10:20:00                    0
# 3440        16:19:00                    0
# 3441        13:00:00                    0
